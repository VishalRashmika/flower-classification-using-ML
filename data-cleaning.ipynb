# %%
from PIL import Image
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_data/rose/1.jpg')
img.shape
# Out:
# (375, 500, 3)

# %%
plt.imshow(img)

# %%
path_to_data = '../../Datasets/flowers/'
path_to_cr_data = './dataset/'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['../../Datasets/flowers/daisy',
#  '../../Datasets/flowers/dandelion',
#  '../../Datasets/flowers/rose',
#  '../../Datasets/flowers/sunflower',
#  '../../Datasets/flowers/tulip']

# %%
cropped_image_dirs = []
flower_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    flower_name = img_dir.split('/')[-1]
    flower_file_names_dict[flower_name] = []
    for entry in os.scandir(img_dir):
        processed_image = Image.open(str(entry.path))
        processed_image = processed_image.resize((200,200))

        cropped_folder = path_to_cr_data + flower_name
        if not os.path.exists(cropped_folder):
            os.makedirs(cropped_folder)
            cropped_image_dirs.append(cropped_folder)
            print("Generating cropped images in folder: ",cropped_folder)
        cropped_file_name = flower_name + str(count) + ".jpg"
        cropped_file_path = cropped_folder + "/" + cropped_file_name
        # cv2.imwrite(cropped_file_path, roi_color)
        #image.save('1-exp.jpeg', "JPEG")
        processed_image.save(cropped_file_path, "JPEG")
        flower_file_names_dict[flower_name].append(cropped_file_path)
        count += 1
# Out:
# Generating cropped images in folder:  ./dataset/daisy
# Generating cropped images in folder:  ./dataset/dandelion
# Generating cropped images in folder:  ./dataset/rose
# Generating cropped images in folder:  ./dataset/sunflower
# Generating cropped images in folder:  ./dataset/tulip

# %%
img = cv2.imread(sth)
plt.imshow(img)
